# %% [markdown]
# <a href="https://colab.research.google.com/github/skredenmathias/Hackathon/blob/master/Squall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyowm

# %%
# from pyowm import OWM
# from pyowm.utils import geo
# from pyowm.alertapi30.enums import WeatherParametersEnum, OperatorsEnum, AlertChannelsEnum
# from pyowm.alertapi30.condition import Condition

import http.client as httplib
import requests, json
import pandas as pd
import time
import requests

# %%
# !git clone https://github.com/skredenmathias/Hackathon.git
# Out:
# fatal: destination path 'Hackathon' already exists and is not an empty directory.

# %%
path = 'https://github.com/skredenmathias/Hackathon/'
boulder = pd.read_excel(path + 'raw/master/boulder_weather.xlsx')
boulder.head()

# %%
# DATA_PATH = 'boulder_weather.xlsx'
# boulder = pd.read_excel(DATA_PATH)

# %%
boulder.head()
# Out:
#                                Month    Jan    Feb  ...  Nov .1  Dec.1    Average
# 0                       Average High  47.00  48.00  ...   54.00  45.00  63.071429
# 1                        Average Low  22.00  23.00  ...   29.00  21.00  36.000000
# 2          Avg precipitation in inch   0.75   0.83  ...    1.22   0.94   1.630000
# 3  Days with percipitation (in inch)   0.00   0.00  ...    0.00   0.00   0.000000
# 4                  Hours of sunshine   0.00   0.00  ...    0.00   0.00   0.000000
#
# [5 rows x 16 columns]

# %%
seattle = pd.read_excel(path + 'raw/master/seattle_weather.xlsx')
seattle.head()
# Out:
#                          Month    Jan     Feb  ...   Nov     Dec     Average
# 0                 Average High  47.00   50.00  ...  51.00  46.00   60.333333
# 1                  Average Low  37.00   37.00  ...  40.00  36.00   45.000000
# 2  Avg precipitation in inches   5.55    0.83  ...   1.22   0.94    2.121667
# 3      Days with percipitation  18.00   14.00  ...  18.00  17.00   12.250000
# 4            Hours of sunshine  69.00  108.00  ...  72.00  52.00  180.250000
#
# [5 rows x 14 columns]

# %%
# SEATTLE_PATH = 'seattle_weather.xlsx'
# seattle = pd.read_excel(SEATTLE_PATH)

# %%
sanfran = pd.read_excel(path + 'raw/master/sanfrancisco_weather.xlsx')
sanfran.head()
# Out:
#                          Month     Jan     Feb  ...    Nov      Dec     Average
# 0                 Average High   57.00   60.00  ...   63.00   57.00   63.666667
# 1                  Average Low   46.00   37.00  ...   50.00   46.00   49.750000
# 2  Avg precipitation in inches    4.49    4.45  ...    3.15    4.57    1.970000
# 3      Days with percipitation   11.00   11.00  ...    7.00   10.00    5.666667
# 4            Hours of sunshine  165.00  182.00  ...  189.00  156.00  245.833333
#
# [5 rows x 14 columns]

# %%
# SANFRANCISCO_PATH = 'sanfrancisco_weather.xlsx'
# sanfran = pd.read_excel(SANFRANCISCO_PATH)

# %%
nyc = pd.read_excel(path + 'raw/master/nyc_weather.xlsx')
nyc.head()
# Out:
#                          Month    Jan     Feb  ...    Nov      Dec     Average
# 0                 Average High   39.0   42.00  ...   54.00   44.00   62.333333
# 1                  Average Low   46.0   37.00  ...   41.00   32.00   51.916667
# 2  Avg precipitation in inches    3.9    2.95  ...    3.82    3.58    3.852500
# 3      Days with percipitation   11.0   10.00  ...    9.00   10.00   10.083333
# 4            Hours of sunshine  154.0  171.00  ...  169.00  155.00  223.083333
#
# [5 rows x 14 columns]

# %%
# NYC_PATH = 'nyc_weather.xlsx'
# nyc = pd.read_excel(NYC_PATH)

# %%
miami = pd.read_excel(path + 'raw/master/miami_weather.xlsx')
miami.head()
# Out:
#                          Month     Jan     Feb  ...    Nov      Dec     Average
# 0                 Average High   76.00   78.00  ...   82.00   78.00   84.166667
# 1                  Average Low   60.00   62.00  ...   68.00   63.00   69.916667
# 2  Avg precipitation in inches    1.61    2.24  ...    3.27    2.05    5.160833
# 3      Days with percipitation    6.00    5.00  ...    8.00    7.00   10.666667
# 4            Hours of sunshine  222.00  227.00  ...  212.00  209.00  241.916667
#
# [5 rows x 14 columns]

# %%
# MIAMI_PATH = 'miami_weather.xlsx'
# miami = pd.read_excel(MIAMI_PATH)

# %% [markdown]
# # LOOK HERE FOR IMPORTANT CODE

# %%
# Console log outside of cell, to store all data
ConsoleLog = []

# %%
# api_key = 'bb57aabd724aacf768c427f96a884d0c'

# base_url = "http://api.openweathermap.org/data/2.5/weather?"

# city_name = input("Enter city name : ") 

# complete_url = base_url + "appid=" + api_key + "&q=" + city_name

# Cold: https://squallhackathon.herokuapp.com/api/alert/ExtremeCold


# TODO:

# Start for loop here. (Include response & x) X COMPLETED

# Continuous deployment # ? X COMPLETED ?

# Delay after ping # COMPLETED

# Log & Print Response X COMPLETED?

# Send text to end user X COMPLETED

while True:
  api_key = 'bb57aabd724aacf768c427f96a884d0c'

  base_url = "http://api.openweathermap.org/data/2.5/weather?"

  city_name = 'Boulder' 

  complete_url = base_url + "appid=" + api_key + "&q=" + city_name

  response = requests.get(complete_url)

  squall_url = requests.post('https://squallhackathon.herokuapp.com/api/alert/')
# json method of response object  
# convert json format data into 
# python format data 
  x = response.json() 

  ConsoleLog.append(x)
  print('Console Log: ', ConsoleLog)

  print("x: ", x)


# Now x contains list of nested dictionaries 
# Check the value of "cod" key is equal to 
# "404", means city is found otherwise, 
# city is not found 

  if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
      y = x["main"] 
      print("y: ", y)  
    
    # store the value corresponding 
    # to the "temp" key of y 
      current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
      current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
      current_humidity = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
      z = x["weather"] 
  
    # store the value of "wind"
    # key in variable w
      w = x["wind"]
      print("w: ", w)

    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
      weather_description = z[0]["description"] 
      print("z: ", z)
      
    # Conditions
    
    # Tornado
      if w['speed'] > 73:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Tornado', json={"city": "Boulder", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Warning: over 73 mph wind speeds. Possible Tornado!"})
        print("Warning: Tornado")
    # Extreme heat
      if y['temp'] > (boulder['Average'][0] + 15 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeHot', json={"city": "Boulder", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme heat conditions."})
        print("Warning: High temp!")
    # Extreme cold
      if y['temp'] < (boulder['Average'][1]-15 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeCold', json={"city": "Boulder", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme cold conditions."})
        print("Warning: low temp!")
    # Snow
      if y['temp'] > 32 and z['main': 'Rain']:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Blizzard', json={"city": "Boulder", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible snowing conditions."})
        print("Warning: Snow!")



    # print following values 
      print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
  
  else: 
      print(" City Not Found ") 
  time.sleep(120)

  # Run again for next city, rinse repeat

  city_name = 'Seattle' 

  complete_url = base_url + "appid=" + api_key + "&q=" + city_name

  response = requests.get(complete_url)

  squall_url = requests.post('https://squallhackathon.herokuapp.com/api/alert/')
# json method of response object  
# convert json format data into 
# python format data 
  x = response.json() 

  ConsoleLog.append(x)
  print('Console Log: ', ConsoleLog)

  print("x: ", x)


  if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
      y = x["main"] 
      print("y: ", y)  
    
    # store the value corresponding 
    # to the "temp" key of y 
      current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
      current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
      current_humidity = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
      z = x["weather"] 
  
    # store the value of "wind"
    # key in variable w
      w = x["wind"]
      print("w: ", w)

    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
      weather_description = z[0]["description"] 
      print("z: ", z)

    # Conditions
    
    # Tornado
      if w['speed'] > 73:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Tornado', json={"city": "Seattle", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Warning: over 73 mph wind speeds. Possible Tornado!"})
        print("Warning: Tornado")
    # Extreme heat
      if y['temp'] > (seattle['Average'][0]+20 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeHot', json={"city": "Seattle", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme heat conditions."})
        print("Warning: High temp!")
    # Extreme cold
      if y['temp'] < (seattle['Average'][1] - 10 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeCold', json={"city": "Seattle", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme cold conditions."})
        print("Warning: low temp!")
    # Snow
      if y['temp'] < 32 and z['main': 'Rain']:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Blizzard', json={"city": "Seattle", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible snowing conditions."})
        print("Warning: Snow!")



    # print following values 
      print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
  
  else: 
      print(" City Not Found ") 

  time.sleep(5)

  # Again, for NYC

  city_name = 'New York' 

  complete_url = base_url + "appid=" + api_key + "&q=" + city_name

  response = requests.get(complete_url)

  squall_url = requests.post('https://squallhackathon.herokuapp.com/api/alert/')
# json method of response object  
# convert json format data into 
# python format data 
  x = response.json() 

  ConsoleLog.append(x)
  print('Console Log: ', ConsoleLog)

  print("x: ", x)


  if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
      y = x["main"] 
      print("y: ", y)  
    
    # store the value corresponding 
    # to the "temp" key of y 
      current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
      current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
      current_humidity = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
      z = x["weather"] 
  
    # store the value of "wind"
    # key in variable w
      w = x["wind"]
      print("w: ", w)

    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
      weather_description = z[0]["description"] 
      print("z: ", z)

    # Conditions
    
    # Tornado
      if w['speed'] > 73:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Tornado', json={"city": "New York", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Warning: over 73 mph wind speeds. Possible Tornado!"})
        print("Warning: Tornado")
    # Extreme heat
      if y['temp'] > (nyc['Average'][0]+30 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeHot', json={"city": "New York", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme heat conditions."})
        print("Warning: High temp!")
    # Extreme cold
      if y['temp'] < (nyc['Average'][1] - 25 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeCold', json={"city": "New York", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme cold conditions."})
        print("Warning: low temp!")
    # Snow
      if y['temp'] < 32 and z['main': 'Rain']:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Blizzard', json={"city": "New York", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible snowing conditions."})
        print("Warning: Snow!")



    # print following values 
      print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
  
  else: 
      print(" City Not Found ") 

  time.sleep(5)

  # Again, for San Francisco

  city_name = 'San Franscisco' 

  complete_url = base_url + "appid=" + api_key + "&q=" + city_name

  response = requests.get(complete_url)

  squall_url = requests.post('https://squallhackathon.herokuapp.com/api/alert/')
# json method of response object  
# convert json format data into 
# python format data 
  x = response.json() 

  ConsoleLog.append(x)
  print('Console Log: ', ConsoleLog)

  print("x: ", x)



  if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
      y = x["main"] 
      print("y: ", y)  
    
    # store the value corresponding 
    # to the "temp" key of y 
      current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
      current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
      current_humidity = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
      z = x["weather"] 
  
    # store the value of "wind"
    # key in variable w
      w = x["wind"]
      print("w: ", w)

    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
      weather_description = z[0]["description"] 
      print("z: ", z)

    # Conditions
    
    # Tornado
      if w['speed'] > 73:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Tornado', json={"city": "San Francisco", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Warning: over 73 mph wind speeds. Possible Tornado!"})
        print("Warning: Tornado")
    # Extreme heat
      if y['temp'] > (sanfran['Average'][0]+15 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeHot', json={"city": "San Francisco", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme heat conditions."})
        print("Warning: High temp!")
    # Extreme cold
      if y['temp'] < (sanfran['Average'][1] - 15 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeCold', json={"city": "San Francisco", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme cold conditions."})
        print("Warning: low temp!")
    # Snow
      if y['temp'] < 32 and z['main': 'Rain']:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Blizzard', json={"city": "San Francisco", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible snowing conditions."})
        print("Warning: Snow!")



    # print following values 
      print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
  
  else: 
      print(" City Not Found ")

  time.sleep(5)

  # Again, for Miami

  city_name = 'Miami' 

  complete_url = base_url + "appid=" + api_key + "&q=" + city_name

  response = requests.get(complete_url)

  squall_url = requests.post('https://squallhackathon.herokuapp.com/api/alert/')
# json method of response object  
# convert json format data into 
# python format data 
  x = response.json() 

  ConsoleLog.append(x)
  print('Console Log: ', ConsoleLog)

  print("x: ", x)



  if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
      y = x["main"] 
      print("y: ", y)  
    
    # store the value corresponding 
    # to the "temp" key of y 
      current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
      current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
      current_humidity = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
      z = x["weather"] 
  
    # store the value of "wind"
    # key in variable w
      w = x["wind"]
      print("w: ", w)

    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
      weather_description = z[0]["description"] 
      print("z: ", z)

    # Conditions
    
    # Tornado
      if w['speed'] > 73:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Tornado', json={"city": "Miami", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Warning: over 73 mph wind speeds. Possible Tornado!"})
        print("Warning: Tornado")
    # Extreme heat
      if y['temp'] > (miami['Average'][0]+10 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeHot', json={"city": "Miami", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme heat conditions."})
        print("Warning: High temp!")
    # Extreme cold
      if y['temp'] < (miami['Average'][1] - 15 + 255.37):
        requests.post('https://squallhackathon.herokuapp.com/api/alert/ExtremeCold', json={"city": "Miami", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible extreme cold conditions."})
        print("Warning: low temp!")
    # Snow
      if y['temp'] < 32 and z['main': 'Rain']:
        requests.post('https://squallhackathon.herokuapp.com/api/alert/Blizzard', json={"city": "Miami", "api_key": "ADFAFqowezEsWgHjHHjMaUFDAfaviosfSFAQDASADFSdF", "message": "Caution: Possible snowing conditions."})
        print("Warning: Snow!")



    # print following values 
      print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
  
  else: 
      print(" City Not Found ")  
  continue
  # break
  # Store response
  # whenever you call the server, always log & print the response
  # So you can see the data
  # grab index of array
  # "console log"
# Out:
# Console Log:  [{'coord': {'lon': -105.27, 'lat': 40.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 277.41, 'feels_like': 269.32, 'temp_min': 268.71, 'temp_max': 281.15, 'pressure': 1018, 'humidity': 22}, 'visibility': 16093, 'wind': {'speed': 6.7, 'deg': 290, 'gust': 8.7}, 'clouds': {'all': 1}, 'dt': 1578075808, 'sys': {'type': 1, 'id': 3958, 'country': 'US', 'sunrise': 1578061386, 'sunset': 1578095243}, 'timezone': -25200, 'id': 5574991, 'name': 'Boulder', 'cod': 200}, {'coord': {'lon': -105.27, 'lat': 40.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 277.41, 'feels_like': 269.32, 'temp_min': 268.71, 'temp_max': 281.15, 'pressure': 1018, 'humidity': 22}, 'visibility': 16093, 'wind': {'speed': 6.7, 'deg': 290, 'gust': 8.7}, 'clouds': {'all': 1}, 'dt': 1578075808, 'sys': {'type': 1, 'id': 3958, 'country': 'US', 'sunrise': 157
# ...

# %%
# # -- conditions --
# condition_1 = Condition(WeatherParametersEnum.TEMPERATURE,
#                         OperatorsEnum.GREATER_THAN,
#                         313.15)  # kelvin
# condition_2 = Condition(WeatherParametersEnum.CLOUDS,
#                         OperatorsEnum.EQUAL,
#                         80) # clouds % coverage

# # -- triggers --

# # create a trigger
# trigger = am.create_trigger(start_after_millis_=355000, end_after_millis=487000,
#                             conditions=[condition_1, condition_2],
#                             area=[geom_1, geom_2],
#                             alert_channel=AlertChannelsEnum.OWM_API)

# # read all triggers
# triggers_list = am.get_triggers()

# # read one named trigger
# trigger_2 = am.get_trigger('trigger_id')

# # update a trigger
# am.update_trigger(trigger_2)

# # delete a trigger
# am.delete_trigger(trigger_2)

# # -- alerts --

# # retrieved from the local parent Trigger obj...
# alerts_list = trigger.get_alerts()
# alerts_list = trigger.get_alerts_since('2018-01-09T23:07:24Z')  # useful for polling alerts
# alerts_list = trigger.get_alerts_on(WeatherParametersEnum.TEMPERATURE)
# alert = trigger.get_alert('alert_id')

# # ...or retrieved from the remote API
# alerts_list_alternate = am.get_alerts_for(trigger)
# alert_alternate = am.get_alert('alert_id')


# # delete all or one alert
# am.delete_all_alerts_for(trigger)
# am.delete_alert_for(trigger, alert)

# %%
# import numpy as np
# import math
# df.head()

# %%
# # Original code
# from pyowm import OWM
# from pyowm.utils import geo
# from pyowm.alertapi30.enums import WeatherParametersEnum, OperatorsEnum, AlertChannelsEnum
# from pyowm.alertapi30.condition import Condition

# # obtain an AlertManager instance
# owm = OWM(API_Key='bb57aabd724aacf768c427f96a884d0c')
# am = owm.alert_manager()

# # -- areas --
# geom_1 = geo.Point(lon, lat)  # available types: Point, MultiPoint, Polygon, MultiPolygon
# geom_1.geojson()
# '''
# {
#   "type": "Point",
#   "coordinates":[ lon, lat ]
# }
# '''
# geom_2 = geo.MultiPolygon([[lon1, lat1], [lon2, lat2], [lon3, lat3], [lon1, lat1]]
#                           [[lon7, lat7], [lon8, lat8], [lon9, lat9], [lon7, lat7]])


# # -- conditions --
# condition_1 = Condition(WeatherParametersEnum.TEMPERATURE,
#                         OperatorsEnum.GREATER_THAN,
#                         313.15)  # kelvin
# condition_2 = Condition(WeatherParametersEnum.CLOUDS,
#                         OperatorsEnum.EQUAL,
#                         80) # clouds % coverage

# # -- triggers --

# # create a trigger
# trigger = am.create_trigger(start_after_millis_=355000, end_after_millis=487000,
#                             conditions=[condition_1, condition_2],
#                             area=[geom_1, geom_2],
#                             alert_channel=AlertChannelsEnum.OWM_API)

# # read all triggers
# triggers_list = am.get_triggers()

# # read one named trigger
# trigger_2 = am.get_trigger('trigger_id')

# # update a trigger
# am.update_trigger(trigger_2)

# # delete a trigger
# am.delete_trigger(trigger_2)

# # -- alerts --

# # retrieved from the local parent Trigger obj...
# alerts_list = trigger.get_alerts()
# alerts_list = trigger.get_alerts_since('2018-01-09T23:07:24Z')  # useful for polling alerts
# alerts_list = trigger.get_alerts_on(WeatherParametersEnum.TEMPERATURE)
# alert = trigger.get_alert('alert_id')

# # ...or retrieved from the remote API
# alerts_list_alternate = am.get_alerts_for(trigger)
# alert_alternate = am.get_alert('alert_id')


# # delete all or one alert
# am.delete_all_alerts_for(trigger)
# am.delete_alert_for(trigger, alert)

# %%
# from pyowm import OWM
# from pyowm.utils import geo
# from pyowm.alertapi30.enums import WeatherParametersEnum, OperatorsEnum, AlertChannelsEnum
# from pyowm.alertapi30.condition import Condition
# from pyowm.alertapi30.enums import AlertChannelsEnum

# API_Key='bb57aabd724aacf768c427f96a884d0c'

# # obtain an AlertManager instance
# owm = OWM(API_Key)
# am = owm.alert_manager()

# # -- areas --
# # owm = pyowm.OWM(API_Key)
# reg = owm.city_id_registry()
# geopoints = reg.geopoints_for('London', country='GB')
# # geom_1 = geo.Point(lon, lat)  # available types: Point, MultiPoint, Polygon, MultiPolygon
# # geom_1.geojson()
# '''
# {
#   "type": "Point",
#   "coordinates":[ lon, lat ]
# }
# '''
# # geom_2 = geo.MultiPolygon([[lon1, lat1], [lon2, lat2], [lon3, lat3], [lon1, lat1]]
# #                           [[lon7, lat7], [lon8, lat8], [lon9, lat9], [lon7, lat7]])


# # -- conditions --
# condition_1 = Condition(WeatherParametersEnum.TEMPERATURE,
#                         OperatorsEnum.GREATER_THAN,
#                         313.15)  # kelvin
# condition_2 = Condition(WeatherParametersEnum.CLOUDS,
#                         OperatorsEnum.EQUAL,
#                         80) # clouds % coverage

# # -- triggers --

# # create a trigger
# trigger = am.create_trigger(start=355000, end=487000,
#                             conditions=[condition_1, condition_2],
#                             area=geopoints,
#                             alert_channels=AlertChannelsEnum.OWM_API_POLLING)


# # am.create_trigger()
# # read all triggers
# triggers_list = am.get_triggers()

# # read one named trigger
# trigger_2 = am.get_trigger('trigger_id')

# # update a trigger
# am.update_trigger(trigger_2)

# # delete a trigger
# am.delete_trigger(trigger_2)

# # -- alerts --

# # retrieved from the local parent Trigger obj...
# alerts_list = trigger.get_alerts()
# alerts_list = trigger.get_alerts_since('2018-01-09T23:07:24Z')  # useful for polling alerts
# alerts_list = trigger.get_alerts_on(WeatherParametersEnum.TEMPERATURE)
# alert = trigger.get_alert('alert_id')

# # ...or retrieved from the remote API
# alerts_list_alternate = am.get_alerts_for(trigger)
# alert_alternate = am.get_alert('alert_id')


# # delete all or one alert
# am.delete_all_alerts_for(trigger)
# am.delete_alert_for(trigger, alert)

# %%
# # Attempting to resolve BadGateWayError by using another method of obtaining
# # city.

# # obtain an AlertManager instance
# owm = OWM(API_Key)
# am = owm.alert_manager()

# # -- areas --
# # owm = pyowm.OWM(API_Key)
# # reg = owm.city_id_registry()
# # geopoints = reg.geopoints_for('London', country='GB')
# geom_1 = geo.Point(-105.271, 40.015)  # available types: Point, MultiPoint, Polygon, MultiPolygon
# geom_1.geojson()
# '''
# {
#   "type": "Point",
#   "coordinates":[ lon, lat ]
# }
# '''
# geom_2 = geo.MultiPolygon([[-73.93, 40.73], [-104.99, 39.74]])# [lon3, lat3], [lon1, lat1]]
#                           #[[lon7, lat7], [lon8, lat8], [lon9, lat9], [lon7, lat7]])

# # -- conditions --
# condition_1 = Condition(WeatherParametersEnum.TEMPERATURE,
#                         OperatorsEnum.GREATER_THAN,
#                         313.15)  # kelvin
# condition_2 = Condition(WeatherParametersEnum.CLOUDS,
#                         OperatorsEnum.EQUAL,
#                         80) # clouds % coverage

# # -- triggers --

# # create a trigger
# trigger = am.create_trigger(start=355000, end=487000,
#                             conditions=[condition_1, condition_2],
#                             area=[geom_1, geom_2],
#                             alert_channels=AlertChannelsEnum.OWM_API_POLLING)
# am.create_trigger()
# # read all triggers
# triggers_list = am.get_triggers()

# # read one named trigger
# trigger_2 = am.get_trigger('trigger_id')

# # update a trigger
# am.update_trigger(trigger_2)

# # delete a trigger
# am.delete_trigger(trigger_2)

# # -- alerts --

# # retrieved from the local parent Trigger obj...
# alerts_list = trigger.get_alerts()
# alerts_list = trigger.get_alerts_since('2018-01-09T23:07:24Z')  # useful for polling alerts
# alerts_list = trigger.get_alerts_on(WeatherParametersEnum.TEMPERATURE)
# alert = trigger.get_alert('alert_id')

# # ...or retrieved from the remote API
# alerts_list_alternate = am.get_alerts_for(trigger)
# alert_alternate = am.get_alert('alert_id')


# # delete all or one alert
# am.delete_all_alerts_for(trigger)
# am.delete_alert_for(trigger, alert)
